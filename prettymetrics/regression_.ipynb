# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/vegetable_price.csv")

# %%
# df.shape

# %%
missing = df.isnull().values.any()

# %%
if missing == True:
    df = df.ffill().bfill()
    print("null values filled")
else:
     print("no null values encountered")
# Out:
# no null values encountered

# %%
from sklearn import preprocessing 
label = preprocessing.LabelEncoder()

# %%
object_col = df.select_dtypes(include=['object']).columns

# %%
for name in object_col:
    df[name] = label.fit_transform(df[name])

# %%
import prettymetrics

from prettymetrics.supervised import LazyRegressor
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:,:-1]
y = df[df.columns[-1]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.3,random_state =123)

# %%
reg = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 56/56 [00:02<00:00, 26.13it/s]

# %%
models
# Out:
#                                                   Adjusted R-Squared  \
# Model
# GradientBoostingRegressor                                       0.71
# ExtraTreeRegressor                                              0.71
# AdaBoostRegressor                                               0.70
# XGBRegressor                                                    0.68
# DecisionTreeRegressor                                           0.64
# ExtraTreesRegressor                                             0.53
# BaggingRegressor                                                0.47
# RandomForestRegressor                                           0.47
# LGBMRegressor                                                   0.16
# HistGradientBoostingRegressor                                   0.15
# GaussianProcessRegressor                                       -0.07
# OrthogonalMatchingPursuitCV                                    -0.13
# OrthogonalMatchingPursuit                                      -0.13
# PLSCanonical                                                   -0.17
# LassoCV                                                        -0.19
# LarsCV                                                         -0.20
# LassoLarsCV                                                    -0.20
# LassoLars                                                      -0.22
# ElasticNet                                                     -0.24
# TweedieRegressor                                               -0.25
# ElasticNetCV                                                   -0.26
# BayesianRidge                                                  -0.27
# ARDRegression                                                  -0.28
# RidgeCV                                                        -0.29
# PLSRegression                                                  -0.29
# Lasso                                                          -0.31
# LassoLarsIC                                                    -0.32
# KNeighborsRegressor                                            -0.32
# GammaRegressor                                                 -0.33
# Ridge                                                          -0.34
# SGDRegressor                                                   -0.34
# Lars                                                           -0.35
# TransformedTargetRegressor                                     -0.35
# LinearRegression                                               -0.35
# PoissonRegressor                                               -0.39
# DummyRegressor                                                 -0.40
# CCA                                                            -0.46
# PassiveAggressiveRegressor                                     -0.59
# HuberRegressor                                                 -0.60
# TheilSenRegressor                                              -0.60
# NuSVR                                                          -0.64
# SVR                                                            -0.82
# LinearSVR                                                      -0.96
# RANSACRegressor                                                -1.10
# MLPRegressor                                                   -1.59
# KernelRidge                                                    -2.19
# RadiusNeighborsRegressor      -5992708532056626368732467633848320.00
#
#                                                            R-Squared  \
# Model
# GradientBoostingRegressor                                       0.76
# ExtraTreeRegressor                                              0.75
# AdaBoostRegressor                                               0.75
# XGBRegressor                                                    0.74
# DecisionTreeRegressor                                           0.70
# ExtraTreesRegressor                                             0.61
# BaggingRegressor                                                0.56
# RandomForestRegressor                                           0.56
# LGBMRegressor                                                   0.30
# HistGradientBoostingRegressor                                   0.29
# GaussianProcessRegressor                                        0.11
# OrthogonalMatchingPursuitCV                                     0.06
# OrthogonalMatchingPursuit                                       0.06
# PLSCanonical                                                    0.02
# LassoCV                                                         0.01
# LarsCV                                                         -0.00
# LassoLarsCV                                                    -0.00
# LassoLars                                                      -0.01
# ElasticNet                                                     -0.03
# TweedieRegressor                                               -0.05
# ElasticNetCV                                                   -0.05
# BayesianRidge                                                  -0.06
# ARDRegression                                                  -0.07
# RidgeCV                                                        -0.07
# PLSRegression                                                  -0.08
# Lasso                                                          -0.09
# LassoLarsIC                                                    -0.10
# KNeighborsRegressor                                            -0.10
# GammaRegressor                                                 -0.10
# Ridge                                                          -0.12
# SGDRegressor                                                   -0.12
# Lars                                                           -0.12
# TransformedTargetRegressor                                     -0.12
# LinearRegression                                               -0.12
# PoissonRegressor                                               -0.16
# DummyRegressor                                                 -0.17
# CCA                                                            -0.21
# PassiveAggressiveRegressor                                     -0.32
# HuberRegressor                                                 -0.33
# TheilSenRegressor                                              -0.34
# NuSVR                                                          -0.36
# SVR                                                            -0.52
# LinearSVR                                                      -0.63
# RANSACRegressor                                                -0.75
# MLPRegressor                                                   -1.16
# KernelRidge                                                    -1.66
# RadiusNeighborsRegressor      -4993923776713855115123472260399104.00
#
#                                                 RMSE  Time Taken
# Model
# GradientBoostingRegressor                      25.94        0.05
# ExtraTreeRegressor                             26.03        0.01
# AdaBoostRegressor                              26.44        0.04
# XGBRegressor                                   26.98        0.25
# DecisionTreeRegressor                          28.79        0.01
# ExtraTreesRegressor                            32.91        0.07
# BaggingRegressor                               34.79        0.02
# RandomForestRegressor                          34.87        0.20
# LGBMRegressor                                  44.01        0.03
# HistGradientBoostingRegressor                  44.21        0.22
# GaussianProcessRegressor                       49.70        0.01
# OrthogonalMatchingPursuitCV                    51.02        0.01
# OrthogonalMatchingPursuit                      51.02        0.01
# PLSCanonical                                   51.93        0.01
# LassoCV                                        52.42        0.13
# LarsCV                                         52.64        0.05
# LassoLarsCV                                    52.64        0.03
# LassoLars                                      52.93        0.02
# ElasticNet                                     53.43        0.01
# TweedieRegressor                               53.74        0.01
# ElasticNetCV                                   53.76        0.04
# BayesianRidge                                  54.15        0.01
# ARDRegression                                  54.31        0.05
# RidgeCV                                        54.43        0.01
# PLSRegression                                  54.57        0.01
# Lasso                                          54.82        0.03
# LassoLarsIC                                    55.11        0.01
# KNeighborsRegressor                            55.21        0.01
# GammaRegressor                                 55.25        0.01
# Ridge                                          55.50        0.01
# SGDRegressor                                   55.53        0.01
# Lars                                           55.69        0.02
# TransformedTargetRegressor                     55.69        0.01
# LinearRegression                               55.69        0.01
# PoissonRegressor                               56.62        0.01
# DummyRegressor                                 56.87        0.01
# CCA                                            57.93        0.01
# PassiveAggressiveRegressor                     60.45        0.01
# HuberRegressor                                 60.70        0.02
# TheilSenRegressor                              60.78        0.41
# NuSVR                                          61.36        0.01
# SVR                                            64.72        0.01
# LinearSVR                                      67.19        0.01
# RANSACRegressor                                69.57        0.06
# MLPRegressor                                   77.25        0.11
# KernelRidge                                    85.65        0.02
# RadiusNeighborsRegressor      3714193195216075264.00        0.01
