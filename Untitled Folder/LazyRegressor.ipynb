# %%
# import necessary modules
import warnings
warnings.filterwarnings('ignore')
import time 
from sklearn.datasets import load_iris,fetch_california_housing
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier,LazyRegressor

# %%
# load the fetch_california_housing dataset
data1=fetch_california_housing()
X1=data1.data
Y1=data1.target

# %%
# split the dataset 
X_train1, X_test1, Y_train1, Y_test1 =train_test_split(X1,Y1,test_size=.3,random_state =23)
regr=LazyRegressor(verbose=0,predictions=True)

# %%
# fit and train the model 
start_time_2=time.time()
models_r,predictions_r=regr.fit(X_train1, X_test1, Y_train1, Y_test1)
end_time_2=time.time()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [01:22<00:00,  1.96s/it]

# %%
# to check which model did better on the fetch_california_housing dataset
models_r
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                                0.84       0.84  0.46        0.17
# HistGradientBoostingRegressor                0.84       0.84  0.46        0.66
# XGBRegressor                                 0.84       0.84  0.47        0.47
# ExtraTreesRegressor                          0.82       0.82  0.50        3.19
# RandomForestRegressor                        0.81       0.81  0.50        7.77
# BaggingRegressor                             0.79       0.79  0.53        0.85
# GradientBoostingRegressor                    0.79       0.79  0.53        2.80
# NuSVR                                        0.77       0.77  0.55        6.32
# SVR                                          0.77       0.77  0.55        5.65
# KNeighborsRegressor                          0.75       0.75  0.58        0.59
# DecisionTreeRegressor                        0.64       0.64  0.69        0.14
# ExtraTreeRegressor                           0.58       0.58  0.75        0.05
# OrthogonalMatchingPursuit                    0.47       0.47  0.84        0.01
# PoissonRegressor                             0.46       0.46  0.85        0.02
# AdaBoostRegressor                            0.44       0.44  0.86        0.84
# LassoCV                                      0.42       0.42  0.89        0.15
# GammaRegressor                               0.39       0.39  0.91        0.02
# MLPRegressor                                 0.37       0.37  0.92        9.87
# ElasticNetCV                                 0.36       0.36  0.93        0.15
# LassoLarsCV                                  0.34       0.34  0.94        0.05
# LarsCV                                       0.34       0.34  0.94        0.05
# TransformedTargetRegressor                   0.31       0.31  0.96        0.02
# LinearRegression                             0.31       0.31  0.96        0.01
# LassoLarsIC                                  0.31       0.31  0.96        0.02
# Lars                                         0.31       0.31  0.96        0.02
# Ridge                                        0.31       0.31  0.96        0.01
# BayesianRidge                                0.31       0.31  0.96        0.02
# RidgeCV                                      0.31       0.31  0.96        0.02
# TweedieRegressor                             0.30       0.30  0.97        0.02
# GeneralizedLinearRegressor                   0.30       0.30  0.97        0.02
# OrthogonalMatchingPursuitCV                  0.26       0.26  1.00        0.03
# ElasticNet                                   0.21       0.21  1.03        0.02
# DummyRegressor                              -0.00      -0.00  1.16        0.01
# LassoLars                                   -0.00      -0.00  1.16        0.02
# Lasso                                       -0.00      -0.00  1.16        0.01
# KernelRidge                                 -2.90      -2.89  2.29       13.39
# RANSACRegressor                             -5.00      -4.99  2.84        0.06
# LinearSVR                                  -10.06     -10.05  3.86        0.49
# HuberRegressor                             -10.97     -10.95  4.01        0.05
# SGDRegressor                               -17.53     -17.50  4.99        0.03
# PassiveAggressiveRegressor                 -18.03     -18.01  5.06        0.02
# GaussianProcessRegressor                  -455.35    -454.76 24.77       28.42

# %%
# to check the predications for the models 
predictions_r
# Out:
#       AdaBoostRegressor  BaggingRegressor  BayesianRidge  \
# 0                  2.34              2.49           2.78
# 1                  3.41              4.10           2.95
# 2                  2.15              1.92           1.59
# 3                  2.18              1.68           2.37
# 4                  2.54              1.31           1.42
# ...                 ...               ...            ...
# 6187               2.80              3.02           2.44
# 6188               1.43              1.20           1.35
# 6189               1.96              1.50           2.05
# 6190               3.07              2.84           2.88
# 6191               2.80              2.71           1.93
#
#       DecisionTreeRegressor  DummyRegressor  ElasticNet  ElasticNetCV  \
# 0                      2.27            2.07        2.10          2.60
# 1                      5.00            2.07        2.19          2.93
# 2                      2.17            2.07        1.96          1.57
# 3                      1.25            2.07        2.05          2.31
# 4                      1.31            2.07        1.83          1.38
# ...                     ...             ...         ...           ...
# 6187                   3.43            2.07        1.99          2.23
# 6188                   1.62            2.07        1.86          1.31
# 6189                   1.25            2.07        1.97          2.03
# 6190                   2.71            2.07        2.18          2.79
# 6191                   1.76            2.07        1.96          1.77
#
#       ExtraTreeRegressor  ExtraTreesRegressor  GammaRegressor  ...  \
# 0                   1.69                 2.54            2.04  ...
# 1                   4.46                 4.15            2.41  ...
# 2                   2.16                 1.71            1.74  ...
# 3                   1.65                 1.80            1.99  ...
# 4                   1.03                 1.32            1.65  ...
# ...                  ...                  ...             ...  ...
# 6187                2.71                 2.92            1.87  ...
# 6188                1.12                 1.14            1.63  ...
# 6189                1.84                 1.87            1.90  ...
# 6190                2.11                 2.56            2.21  ...
# 6191                2.55                 2.40            1.75  ...
#
#       RANSACRegressor  RandomForestRegressor  Ridge  RidgeCV  SGDRegressor  \
# 0                2.80                   2.46   2.78     2.77          2.73
# 1                3.11                   4.32   2.95     2.95          2.66
# 2                1.64                   1.76   1.59     1.58          1.46
# 3                2.32                   1.69   2.37     2.37          2.28
# 4                1.61                   1.31   1.42     1.42          1.09
# ...               ...                    ...    ...      ...           ...
# 6187             2.54                   3.11   2.44     2.43          2.14
# 6188             1.45                   1.17   1.35     1.34          1.24
# 6189             2.09                   1.61   2.05     2.05          1.78
# 6190             2.87                   2.74   2.88     2.88          2.87
# 6191             1.97                   2.32   1.93     1.93          1.59
#
#       SVR  TransformedTargetRegressor  TweedieRegressor  XGBRegressor  \
# 0    2.67                        2.78              2.17          2.44
# 1    3.90                        2.95              2.53          5.02
# 2    1.52                        1.59              1.79          1.82
# 3    2.04                        2.37              2.11          1.55
# 4    1.35                        1.42              1.65          1.47
# ...   ...                         ...               ...           ...
# 6187 2.86                        2.44              1.97          3.11
# 6188 1.18                        1.35              1.62          1.30
# 6189 2.06                        2.05              2.02          1.57
# 6190 2.82                        2.88              2.35          2.86
# 6191 2.26                        1.93              1.79          1.91
#
#       LGBMRegressor
# 0              2.58
# 1              4.82
# 2              1.72
# 3              1.58
# 4              1.28
# ...             ...
# 6187           3.01
# 6188           1.09
# 6189           1.57
# 6190           3.02
# 6191           2.18
#
# [6192 rows x 42 columns]

# %%
# time complexity 
print("The time taken by LazyRegressor for {0} samples is {1} ms".format(len(data1.data),round(end_time_2-start_time_2,0)))
# Out:
# The time taken by LazyRegressor for 20640 samples is 83.0 ms
